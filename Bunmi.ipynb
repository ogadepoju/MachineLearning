# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
new_data = pd.read_csv('C:\\Users\\ODUNAYO\\Desktop\\ph\\Assignment\\datasets\\train.csv')

# %%
new_data.head()
# Out:
#    S/N Gender  Age Location famsize Pstatus  Medu  Fedu  traveltime  \
# 0    1      F   13        U     GT3       A     4     4           2
# 1    2      F   12        U     GT3       T     1     1           1
# 2    3      F   10        U     LE3       T     1     1           1
# 3    4      F   10        U     GT3       T     4     2           1
# 4    5      F   11        U     GT3       T     3     3           1
#
#    studytime  ...    paid activities nursery higher internet famrel freetime  \
# 0          2  ...      no         no     yes    yes       no      4        3
# 1          2  ...      no         no      no    yes      yes      5        3
# 2          2  ...      no         no     yes    yes      yes      4        3
# 3          3  ...      no        yes     yes    yes      yes      3        2
# 4          2  ...      no         no     yes    yes       no      4        3
#
#   health  absences  Score
# 0      3         4     22
# 1      3         2     31
# ...

# %%
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 325 entries, 0 to 324
# Data columns (total 23 columns):
# S/N           325 non-null int64
# Gender        325 non-null object
# Age           325 non-null int64
# Location      325 non-null object
# famsize       325 non-null object
# Pstatus       325 non-null object
# Medu          325 non-null int64
# Fedu          325 non-null int64
# traveltime    325 non-null int64
# studytime     325 non-null int64
# failures      325 non-null int64
# schoolsup     325 non-null object
# famsup        325 non-null object
# paid          325 non-null object
# activities    325 non-null object
# nursery       325 non-null object
# higher        325 non-null object
# internet      325 non-null object
# famrel        325 non-null int64
# freetime      325 non-null int64
# health        325 non-null int64
# absences      325 non-null int64
# Score         325 non-null int64
# dtypes: int64(12), object(11)
# memory usage: 58.5+ KB

# %%
new_data.isnull().sum()
# Out:
# S/N           0
# Gender        0
# Age           0
# Location      0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# famrel        0
# freetime      0
# health        0
# absences      0
# Score         0
# dtype: int64

# %%
new_data.describe()
# Out:
#               S/N         Age        Medu        Fedu  traveltime   studytime  \
# count  325.000000  325.000000  325.000000  325.000000  325.000000  325.000000
# mean   163.000000   11.320000    2.710769    2.476923    1.449231    1.956923
# std     93.963645    1.123157    1.086977    1.093015    0.725234    0.819133
# min      1.000000   10.000000    0.000000    0.000000    1.000000    1.000000
# 25%     82.000000   10.000000    2.000000    2.000000    1.000000    1.000000
# 50%    163.000000   11.000000    3.000000    2.000000    1.000000    2.000000
# 75%    244.000000   12.000000    4.000000    3.000000    2.000000    2.000000
# max    325.000000   17.000000    4.000000    4.000000    4.000000    4.000000
#
#          failures      famrel    freetime      health    absences       Score
# count  325.000000  325.000000  325.000000  325.000000  325.000000  325.000000
# mean     0.184615    3.926154    3.178462    3.590769    4.341538   35.713846
# ...

# %%
df = new_data[['Fedu', 'Medu', 'studytime', 'freetime', 'health', 'absences', 'Gender',]]

# %%
df.corr()
# Out:
#                Fedu      Medu  studytime  freetime    health  absences
# Fedu       1.000000  0.625634  -0.004561  0.018134  0.008697  0.059223
# Medu       0.625634  1.000000   0.089956  0.019491 -0.030529 -0.032706
# studytime -0.004561  0.089956   1.000000 -0.127890 -0.070006 -0.129136
# freetime   0.018134  0.019491  -0.127890  1.000000  0.095062 -0.046790
# health     0.008697 -0.030529  -0.070006  0.095062  1.000000 -0.064186
# absences   0.059223 -0.032706  -0.129136 -0.046790 -0.064186  1.000000

# %%
import seaborn as sns
corr_matrix = new_data.corr()
f, ax = plt.subplots(figsize=(18,10))
sns.heatmap(corr_matrix, linewidths = 2.0, ax = ax, annot = True)
ax.set_title('Correlation Matrix')
# Out:
# Text(0.5,1,'Correlation Matrix')

# %%
real_data = new_data[new_data.columns.difference(['S/N'])]

# %%
real_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 325 entries, 0 to 324
# Data columns (total 22 columns):
# Age           325 non-null int64
# Fedu          325 non-null int64
# Gender        325 non-null object
# Location      325 non-null object
# Medu          325 non-null int64
# Pstatus       325 non-null object
# Score         325 non-null int64
# absences      325 non-null int64
# activities    325 non-null object
# failures      325 non-null int64
# famrel        325 non-null int64
# famsize       325 non-null object
# famsup        325 non-null object
# freetime      325 non-null int64
# health        325 non-null int64
# higher        325 non-null object
# internet      325 non-null object
# nursery       325 non-null object
# paid          325 non-null object
# schoolsup     325 non-null object
# studytime     325 non-null int64
# traveltime    325 non-null int64
# dtypes: int64(11), object(11)
# memory usage: 55.9+ KB

# %%
real_data.iloc[0:7, 0:13]
# Out:
#    Age  Fedu Gender Location  Medu Pstatus  Score  absences activities  \
# 0   13     4      F        U     4       A     22         4         no
# 1   12     1      F        U     1       T     31         2         no
# 2   10     1      F        U     1       T     37         6         no
# 3   10     2      F        U     4       T     42         0        yes
# 4   11     3      F        U     3       T     37         0         no
# 5   11     3      M        U     4       T     37         6        yes
# 6   11     2      M        U     2       T     38         0         no
#
#    failures  famrel famsize famsup
# 0         0       4     GT3     no
# 1         0       5     GT3    yes
# 2         0       4     LE3     no
# 3         0       3     GT3    yes
# 4         0       4     GT3    yes
# 5         0       5     LE3    yes
# 6         0       4     LE3     no

# %%
real_data.iloc[0:7, 13:]
# Out:
#    freetime  health higher internet nursery paid schoolsup  studytime  \
# 0         3       3    yes       no     yes   no       yes          2
# 1         3       3    yes      yes      no   no        no          2
# 2         3       3    yes      yes     yes   no       yes          2
# 3         2       5    yes      yes     yes   no        no          3
# 4         3       5    yes       no     yes   no        no          2
# 5         4       5    yes      yes     yes   no        no          2
# 6         4       3    yes      yes     yes   no        no          2
#
#    traveltime
# 0           2
# 1           1
# 2           1
# 3           1
# 4           1
# 5           1
# 6           1

# %%
values = {"activities": {"no":0,"yes":1}, "Gender":{"F":0, "M":1}, "famsup":{"no":0,"yes":1}, 
          "higher":{"no":0,"yes":1}, "internet":{"no":0,"yes":1}, "nursery":{"no":0,"yes":1}, 
          "paid":{"no":0,"yes":1}, "schoolsup":{"no":0,"yes":1}, "Pstatus":{"T":1, "A":0}, 
          "famsize":{"LE3":0, "GT3":1}, "Location":{"U":0, "R":1}}
real_data.replace(values, inplace=True)
# Out:
# C:\Users\ODUNAYO\Anaconda3\lib\site-packages\pandas\core\generic.py:5817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   regex=regex)

# %%
corr_matrix = real_data.corr()
f, ax = plt.subplots(figsize=(18, 10))
sns.heatmap(corr_matrix, linewidths=2.0, ax=ax, annot=True)
ax.set_title('Correlation Matrix')
# Out:
# Text(0.5,1,'Correlation Matrix')

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
lm = LinearRegression()

# %%
real_data.head()
# Out:
#    Age  Fedu  Gender  Location  Medu  Pstatus  Score  absences  activities  \
# 0   13     4       0         0     4        0     22         4           0
# 1   12     1       0         0     1        1     31         2           0
# 2   10     1       0         0     1        1     37         6           0
# 3   10     2       0         0     4        1     42         0           1
# 4   11     3       0         0     3        1     37         0           0
#
#    failures     ...      famsup  freetime  health  higher  internet  nursery  \
# 0         0     ...           0         3       3       1         0        1
# 1         0     ...           1         3       3       1         1        0
# 2         0     ...           0         3       3       1         1        1
# 3         0     ...           1         2       5       1         1        1
# 4         0     ...           1         3       5       1         0        1
#
#    paid  schoolsup  studytime  traveltime
# ...

# %%
sns.pairplot(data=real_data, x_vars=['higher', 'paid', 'Medu', 'studytime','traveltime','Location','absences'], y_vars=['Score'])

# %%
data1 = pd.read_csv('C:\\Users\\ODUNAYO\\Desktop\\ph\\Assignment\\datasets\\test.csv')

# %%
data1.head()
# Out:
#    S/N  Age Location famsize Pstatus  Medu  Fedu  traveltime  studytime  \
# 0  327   12        U     LE3       A     3     2           1          1
# 1  328   13        R     LE3       T     1     1           2          4
# 2  329   13        U     GT3       T     1     1           2          2
# 3  330   12        U     GT3       T     2     2           1          2
# 4  331   13        U     GT3       T     2     1           2          2
#
#    failures    ...    famsup paid activities nursery higher internet famrel  \
# 0         0    ...        no   no         no     yes    yes      yes      4
# 1         0    ...       yes   no        yes     yes    yes       no      5
# 2         0    ...        no   no        yes     yes    yes      yes      5
# 3         0    ...       yes   no         no      no    yes      yes      5
# 4         0    ...        no   no        yes     yes    yes      yes      4
#
#    freetime  health  absences
# 0         4       3        18
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 323 entries, 0 to 322
# Data columns (total 21 columns):
# S/N           323 non-null int64
# Age           323 non-null int64
# Location      323 non-null object
# famsize       323 non-null object
# Pstatus       323 non-null object
# Medu          323 non-null int64
# Fedu          323 non-null int64
# traveltime    323 non-null int64
# studytime     323 non-null int64
# failures      323 non-null int64
# schoolsup     323 non-null object
# famsup        323 non-null object
# paid          323 non-null object
# activities    323 non-null object
# nursery       323 non-null object
# higher        323 non-null object
# internet      323 non-null object
# famrel        323 non-null int64
# freetime      323 non-null int64
# health        323 non-null int64
# absences      323 non-null int64
# dtypes: int64(11), object(10)
# memory usage: 53.1+ KB

# %%
data1.isnull().sum()
# Out:
# S/N           0
# Age           0
# Location      0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# famrel        0
# freetime      0
# health        0
# absences      0
# dtype: int64

# %%
import seaborn as sns
corr_matrix = data1.corr()
f, ax = plt.subplots(figsize=(18,10))
sns.heatmap(corr_matrix, linewidths = 2.0, ax = ax, annot = True)
ax.set_title('Correlation Matrix')
# Out:
# Text(0.5,1,'Correlation Matrix')

# %%
data1.iloc[0:7, 0:13]
# Out:
#    S/N  Age Location famsize Pstatus  Medu  Fedu  traveltime  studytime  \
# 0  327   12        U     LE3       A     3     2           1          1
# 1  328   13        R     LE3       T     1     1           2          4
# 2  329   13        U     GT3       T     1     1           2          2
# 3  330   12        U     GT3       T     2     2           1          2
# 4  331   13        U     GT3       T     2     1           2          2
# 5  332   12        U     GT3       T     1     1           1          2
# 6  333   13        U     GT3       T     2     2           1          3
#
#    failures schoolsup famsup paid
# 0         0        no     no   no
# 1         0        no    yes   no
# 2         0       yes     no   no
# 3         0        no    yes   no
# 4         0        no     no   no
# 5         0        no     no   no
# 6         0        no    yes   no

# %%
data1.iloc[0:7, 13:]
# Out:
#   activities nursery higher internet  famrel  freetime  health  absences
# 0         no     yes    yes      yes       4         4       3        18
# 1        yes     yes    yes       no       5         2       3         2
# 2        yes     yes    yes      yes       5         4       4         0
# 3         no      no    yes      yes       5         4       5        12
# 4        yes     yes    yes      yes       4         3       5        10
# 5         no      no    yes      yes       4         3       4         0
# 6         no     yes    yes      yes       4         3       2         0

# %%
values = {"activities": {"no":1,"yes":2}, "Gender":{"F":1, "M":2}, "famsup":{"no":1,"yes":2}, 
          "higher":{"no":1,"yes":2}, "internet":{"no":1,"yes":2}, "nursery":{"no":1,"yes":2}, 
          "paid":{"no":1,"yes":2}, "schoolsup":{"no":1,"yes":2}, "Pstatus":{"T":1, "A":2}, 
          "famsize":{"LE3":1, "GT3":2}, "Location":{"U":1, "R":2}}
data1.replace(values, inplace=True)

# %%
corr_matrix = data1.corr()
f, ax = plt.subplots(figsize=(18, 10))
sns.heatmap(corr_matrix, linewidths=2.0, ax=ax, annot=True)
ax.set_title('Correlation Matrix')
# Out:
# Text(0.5,1,'Correlation Matrix')

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
lm = LinearRegression()

# %%
data1.head()
# Out:
#    S/N  Age  Location  famsize  Pstatus  Medu  Fedu  traveltime  studytime  \
# 0  327   12         1        1        2     3     2           1          1
# 1  328   13         2        1        1     1     1           2          4
# 2  329   13         1        2        1     1     1           2          2
# 3  330   12         1        2        1     2     2           1          2
# 4  331   13         1        2        1     2     1           2          2
#
#    failures    ...     famsup  paid  activities  nursery  higher  internet  \
# 0         0    ...          1     1           1        2       2         2
# 1         0    ...          2     1           2        2       2         1
# 2         0    ...          1     1           2        2       2         2
# 3         0    ...          2     1           1        1       2         2
# 4         0    ...          1     1           2        2       2         2
#
#    famrel  freetime  health  absences
# ...

# %%
sns.pairplot(data=real_data, x_vars=['higher', 'paid', 'Medu', 'studytime','traveltime','Location','absences'], y_vars=['Score'])

# %%
negative_corr = real_data[['Age','failures', 'absences']]

# %%
positive_corr = real_data[['higher', 'activities', 'Medu', 'studytime']]

# %%
gen_data = real_data[['higher', 'activities', 'Medu', 'studytime', 'Age','failures', 'absences']]

# %%
negative_corr.describe()
# Out:
#               Age    failures    absences
# count  325.000000  325.000000  325.000000
# mean    11.320000    0.184615    4.341538
# std      1.123157    0.579812    5.200038
# min     10.000000    0.000000    0.000000
# 25%     10.000000    0.000000    0.000000
# 50%     11.000000    0.000000    2.000000
# 75%     12.000000    0.000000    6.000000
# max     17.000000    3.000000   32.000000

# %%
negative_corr.groupby(['Age'])['Age'].count()
# Out:
# Age
# 10     86
# 11    112
# 12     77
# 13     41
# 14      7
# 15      1
# 17      1
# Name: Age, dtype: int64

# %%
negative_corr.groupby(['failures'])['failures'].count()
# Out:
# failures
# 0    287
# 1     24
# 2      6
# 3      8
# Name: failures, dtype: int64

# %%
negative_corr.groupby(['absences'])['absences'].count()
# Out:
# absences
# 0     103
# 1       1
# 2      63
# 4      54
# 6      33
# 7       2
# 8      21
# 9       1
# 10     15
# 12      7
# 14      7
# 15      2
# 16      9
# 18      1
# 21      1
# 22      1
# 24      1
# 26      1
# 30      1
# 32      1
# Name: absences, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
lm = LinearRegression()

# %%
real_data.head()
# Out:
#    Age  Fedu  Gender  Location  Medu  Pstatus  Score  absences  activities  \
# 0   13     4       0         0     4        0     22         4           0
# 1   12     1       0         0     1        1     31         2           0
# 2   10     1       0         0     1        1     37         6           0
# 3   10     2       0         0     4        1     42         0           1
# 4   11     3       0         0     3        1     37         0           0
#
#    failures     ...      famsup  freetime  health  higher  internet  nursery  \
# 0         0     ...           0         3       3       1         0        1
# 1         0     ...           1         3       3       1         1        0
# 2         0     ...           0         3       3       1         1        1
# 3         0     ...           1         2       5       1         1        1
# 4         0     ...           1         3       5       1         0        1
#
#    paid  schoolsup  studytime  traveltime
# ...

# %%
x_train, x_test, y_train, y_test = train_test_split(gen_data, real_data.Score, test_size=0.33, random_state=5)

# %%
lm.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
y_train
# Out:
# 168    23
# 276    47
# 119    41
# 314    51
# 6      38
# 259    31
# 134    37
# 163    20
# 155    22
# 149    31
# 37     39
# 131    27
# 167    39
# 71     30
# 271    34
# 18     23
# 270    44
# 93     41
# 178    24
# 2      37
# 95     39
# 23     30
# 3      42
# 251    29
# 28     37
# 248    27
# 266    43
# 303    40
# 198    45
# 145    28
#        ..
# 5      37
# 144    34
# 103    31
# 210    40
# 41     32
# 137    35
# 254    27
# 146    30
# 125    27
# 86     35
# 30     32
# 65     47
# 203    28
# 205    35
# 44     32
# 27     33
# 80     34
# 113    53
# 204    37
# 7      36
# 208    37
# 158    33
# 112    28
# 231    30
# 228    34
# 8      48
# 73     40
# 118    34
# 189    32
# 206    33
# Name: Score, Length: 217, dtype: int64

# %%
y_test
# Out:
# 290    31
# 127    30
# 138    34
# 263    23
# 83     38
# 42     44
# 132    32
# 47     51
# 60     49
# 202    39
# 162    34
# 322    27
# 55     37
# 154    32
# 76     34
# 53     37
# 48     36
# 21     35
# 226    39
# 181    52
# 182    37
# 282    22
# 291    32
# 107    41
# 238    47
# 75     33
# 185    51
# 66     35
# 239    24
# 153    39
#        ..
# 39     39
# 102    37
# 108    33
# 25     33
# 98     38
# 223    35
# 84     37
# 61     36
# 51     46
# 193    35
# 26     35
# 141    40
# 11     35
# 159    38
# 17     41
# 142    34
# 67     29
# 222    38
# 96     31
# 68     32
# 186    30
# 140    29
# 288    37
# 199    38
# 262    26
# 252    40
# 297    29
# 90     31
# 89     28
# 197    41
# Name: Score, Length: 108, dtype: int64

# %%
pred_train = lm.predict(x_train)
pred_test = lm.predict(x_test)

# %%
len(pred_test)
# Out:
# 108

# %%
len(pred_train)
# Out:
# 217

# %%
x = mean_squared_error(y_test, pred_test)

# %%
x**0.5
# Out:
# 5.39791641568699

# %%
pd.DataFrame(pred_train).to_csv('predicted1.csv')

# %%
pd.DataFrame(pred_test).to_csv('predicted2.csv')
